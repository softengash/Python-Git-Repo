# %% [markdown]
# 1A

# %%
array = [['a','b','c'],['d','e','f']]

# %%
for item in sum(array,[]):
    print item
# Out:
# a
# b
# c
# d
# e
# f

# %% [raw]
# 1B
# Have a look at "programming-tasks/top10_sample.csv"
# Each line in this file represents a list of Brand in our store.
# Write a script to print out a list of brand names and their occurrence counts (sorted).

# %%
class MapReduce:
    def __init__(self):
        self.intermediate = {}
        self.result = []

    def emit_intermediate(self, key, value):
        self.intermediate.setdefault(key, [])
        self.intermediate[key].append(value)

    def emit(self, value):
        self.result.append(value) 

    def execute(self, data, mapper, reducer):
        for line in data:
            mapper(line)

        for key in self.intermediate:
            reducer(key, self.intermediate[key])

# %%
mr = MapReduce()

def mapper(record):
    brands = record[0].replace('[','').replace(']','').split(',')
    for brand in brands:
      mr.emit_intermediate(brand, 1)

def reducer(key, list_of_values):
    total = 0
    for v in list_of_values:
      total += v
    mr.emit((key, total))

# %%
import csv

data = open('top10_sample.csv')
inputdata = csv.reader(data)
mr.execute(inputdata, mapper, reducer)
data.close()

#for k,v in sorted(mr.intermediate.items()):
#    print k,v


for item in sorted(mr.result):
    print item
# Out:
# ('24:01', 795)
# ('2pm.com', 380)
# ('66\xc2\xb030', 1)
# ('A Time Machine', 24)
# ('ACCA KAPPA', 6)
# ('ALBA', 41)
# ('ALDO', 129)
# ('AMBROS', 108)
# ('AR by Alfio Raldo', 63)
# ('ASTALIFT', 1)
# ('ATYPICAL', 36)
# ('ATYPICAL Premium', 19)
# ('AVI-8', 61)
# ('AVIVA', 13)
# ('Abaya Suraya', 4)
# ('Ad Jeans', 124)
# ('Adidas', 15)
# ('Admiral', 48)
# ('Aigner', 4)
# ('Albertini', 139)
# ('Alcott', 5)
# ('Alfio Raldo', 33)
# ('Alfio Raldo Men', 25)
# ('Alfio Raldo Young', 1)
# ('Alim by Alana Ilham', 11)
# ('All That Glitters', 5)
# ('American Apparel', 44)
# ('American Crew', 4)
# ('Amir Luqman for Zalora', 3)
# ('Amnig', 211)
# ('Anglia', 1)
# ('Anne Klein', 9)
# ('Anonymous', 1)
# ('Another', 2)
# ('Appetime', 1)
# ('Armani Exchange', 5)
# ('Arno Sorel', 1)
# ('Asian Ethnic', 4)
# ('Avalanche', 10)
# ('Axel', 26)
# ('Azer', 14)
# ('BLAKE & CO', 1)
# ('BY TWO PEAS FOOTWEAR', 1)
# ('BYN', 21)
# ('Baby G', 11)
# ('Bagman', 147)
# ('Barefoot X Barefy', 5)
# ('Bata', 124)
# ('BeBe', 4)
# ('Beauty Clinic Mediheal', 3)
# ('Ben Sherman - UK ', 1)
# ('Beverly Hills Polo Club', 42)
# ('Bill Keith', 2)
# ('Biondini by Shoeville', 1)
# ('Birkenstock', 9)
# ('Black Queen', 33)
# ('Blue Exchange', 159)
# ('Body Glove', 207)
# ('Boutique 9', 1)
# ('Bravado', 12)
# ('Brooks Brothers', 4)
# ('Bulova', 27)
# ('Bum Equipment', 149)
# ('Bungor', 2)
# ('CATWALK 88', 28)
# ('CHANICE', 12)
# ('CHOC O LATTE', 3)
# ('CLOSET', 1)
# ('COVEQ London', 12)
# ('CR2', 5)
# ('Caelygirl', 37)
# ('Carlo Cardini', 83)
# ('Carlo Rino', 26)
# ('Casio', 235)
# ('Cats Whiskers', 26)
# ('Catwalk', 4)
# ('Cayla Rae', 4)
# ('Celsius', 7)
# ('Cheap Monday', 75)
# ('Chic Yamada', 1)
# ('Christy Ng', 1)
# ('Chuck&Bo', 1)
# ('Ciracle', 3)
# ('Comoddity', 1)
# ('Contessa', 2)
# ('Converse', 142)
# ('Cookoo', 5)
# ('Crazeecausa', 30)
# ('Criss Cross', 105)
# ('Cross', 46)
# ('DC Shoes', 24)
# ('DKNY', 3)
# ('Dandelion', 13)
# ('Danish Design', 7)
# ('David Beckham', 22)
# ('Dear Body', 4)
# ('Desigual', 1)
# ('Dr. Martens', 64)
# ('Dumond', 3)
# ('Dumond by Shoeville', 1)
# ('ECHO Park', 15)
# ('EDGE', 15)
# ('ELLEgirl', 7)
# ('EVO', 163)
# ('EZRA', 1670)
# ('EZRA Basics', 30)
# ('Earnshaw', 8)
# ('Ed Hardy', 20)
# ('Edwin', 69)
# ('Electro Denim Lab', 45)
# ('Elizabeth Arden', 3)
# ('Embellish', 54)
# ('Emmer Zecna', 73)
# ('Emporio Armani', 9)
# ('Emruti', 9)
# ('Enjoy', 22)
# ('Enzo Angiolini', 1)
# ('Esprit', 13)
# ('Ethnic Chic', 105)
# ('Ethnic Chic Ayu', 31)
# ('Everlast', 34)
# ('Evernodd', 1)
# ('Extreme X Zero Hour', 162)
# ('Eyki', 196)
# ('FCC', 3)
# ('FCUK', 16)
# ('FLESH IMP', 65)
# ('FMFA x ZALORA', 67)
# ('FMS by Radioactive', 10)
# ('Fashion.LAB', 54)
# ('Ferrari', 22)
# ('Fila', 21)
# ('First Lady', 78)
# ('FitnessLAB', 1)
# ('Fjord', 12)
# ('Forte', 8)
# ('Fossil', 28)
# ('Fourskin', 107)
# ("Fox's Accessories", 16)
# ('Frangipani Closet', 14)
# ('Frankiemumbo', 1)
# ('Free Range Kids', 2)
# ('Fullspot', 7)
# ('Funk', 70)
# ('G-shock', 70)
# ('G. Davin', 11)
# ('GAROOS', 30)
# ('GPPC', 64)
# ('GS Polo', 10)
# ('Galliano', 1)
# ('Garden of Eden', 2)
# ('Gaston & co', 1)
# ('Geb.', 15)
# ('Gene Martino', 1)
# ('Gildan', 2)
# ('Gin & Jacqie', 8)
# ('Giordano', 6)
# ('Giordano Eyewear', 1)
# ('Gisa', 1)
# ('Grendha', 2)
# ('Guess', 30)
# ('HIDDEN', 41)
# ('Harvard Polo Club', 40)
# ('Hatta', 33)
# ('Havaianas', 35)
# ('Heatwave', 8)
# ('Herschel', 84)
# ('Hi Style', 132)
# ('Hidesign', 36)
# ('High Cultured', 143)
# ('Hoola by CommonThread', 7)
# ('Hotto Windo @ Tropicana Life', 20)
# ('House Of Harlow 1960', 5)
# ('Humor', 5)
# ('Hypergear', 201)
# ('I.C by Inner Circle', 7)
# ('IAMJETFUEL', 2)
# ('ICE dressme', 15)
# ('INDEPENDENT by Citizen', 6)
# ('IZO Jeans', 45)
# ('Ibby Libby', 5)
# ('Ice Watch', 60)
# ('Icollection', 18)
# ('Inner Circle', 17)
# ('Inner Circle CNY', 1)
# ('Ipanema', 12)
# ('JAXON', 1272)
# ('JAZZ STAR', 29)
# ('JEFFERSON', 517)
# ('JJ Mastini', 47)
# ('JLuxe', 49)
# ('JO JO NEW YORK', 17)
# ('Jack & Jones', 50)
# ('Jacqueline Burchell', 2)
# ('Jae Homme', 70)
# ('Jameela Muslimah', 21)
# ('Jane Holli', 6)
# ('Jean Christophe', 1)
# ('Jendela KL', 1)
# ('Jennifer Lopez', 1)
# ('Jhijab', 2)
# ('John Varvatos', 12)
# ('Joie Mie', 5)
# ('Jovian Mandagie for Zalora', 9)
# ('Jovian by Jovian Mandagie', 3)
# ('Juicy Couture', 1)
# ('Juli LA', 1)
# ('Just Cavalli', 1)
# ('Justin Bieber', 2)
# ('K-Swiss', 9)
# ('KLF', 80)
# ('KN KEY NG', 19)
# ('KYOKU', 1)
# ('Kappa', 90)
# ('Keds', 2)
# ('Kei&Kori', 259)
# ('Kenneth Cole', 3)
# ('Kenneth Cole Reaction', 2)
# ('Kiss & Tell', 13)
# ('Kiss Me', 2)
# ('Knight', 359)
# ('Komono', 22)
# ('Koumi Koumi', 75)
# ("L'Oreal Professionnel", 1)
# ('LASH', 30)
# ('LELA LOVE', 3)
# ('LEXON', 2)
# ('LINE 7', 71)
# ('LIOELE', 6)
# ('LS for Jovian', 20)
# ('LUXE by Ethnic Chic', 64)
# ('Larrie', 3)
# ('Latinas', 6)
# ('Lavina', 6)
# ('Laviss', 17)
# ('Le Ann', 5)
# ('Le Petit Olivier', 13)
# ('Le Sandee', 13)
# ('Lee Cooper', 139)
# ("Levi's", 450)
# ('Lierac', 1)
# ("Lilly's Closet", 1)
# ('Limkokwing Fashion Club', 40)
# ('Line', 20)
# ('Loaded @ Unity Store KL', 3)
# ('Lois', 116)
# ('Looney Tunes @ urban TEE', 34)
# ('Lotto', 4)
# ('Louis Cuppers', 402)
# ('Luth Ali', 5)
# ('M & N', 2)
# ('MALVIC CUFFS', 31)
# ('MANGO', 266)
# ('MICHAEL KORS', 9)
# ('ML x AC', 19)
# ('MS. READ', 9)
# ('Macbeth', 341)
# ('Macerio', 123)
# ('Manchester United', 49)
# ('Mariah Carey', 2)
# ('Marie Claire', 23)
# ('Marry Merry', 6)
# ('Masked Rider @ urban TEE', 15)
# ('MazBrasil', 27)
# ('Me&City', 4)
# ('Mediental', 3)
# ('Medium Rare Store', 9)
# ('Melissa', 45)
# ('MiL', 68)
# ('Micffy', 6)
# ('Mickey', 1)
# ('Miss Sixty', 3)
# ('Monarchii', 4)
# ('Monkee Genes', 31)
# ('Moonriver', 6)
# ('Moschino', 1)
# ('Murad', 3)
# ('Mylovewear', 1)
# ('NCLA', 2)
# ('Najjah', 4)
# ('Neverland', 267)
# ('New Balance', 220)
# ('New Era', 76)
# ('New Look', 58)
# ('Newmen', 34)
# ('Nike', 1141)
# ('Nine West', 21)
# ('Nine West Exclusive', 54)
# ('Nioxin', 3)
# ('North Star', 100)
# ('Nose', 85)
# ('Noveni', 7)
# ('Nukleus', 155)
# ('ONLY', 12)
# ('OPI', 10)
# ('ORIENT', 16)
# ('OSIS+', 1)
# ('Olay', 10)
# ('Omax', 26)
# ('Organic Surge', 2)
# ('Oscar de la Renta', 1)
# ('Osmium for Men', 2)
# ('PAKU', 1)
# ('PLAYBOY BUNNY', 42)
# ('POSSE', 1)
# ('POTS-1 Contemporary', 4)
# ('POTS-1 Modern Lifestyle', 7)
# ('Palio', 48)
# ('Parfois', 17)
# ('Paris Hilton', 3)
# ('Passion', 38)
# ('Payot', 2)
# ("People's", 128)
# ('Pestle & Mortar', 178)
# ('Phyto', 12)
# ("Pink Evil's Fashion Supermarket", 2)
# ('Playboy', 529)
# ('Police', 12)
# ('Polo', 191)
# ('Power', 107)
# ('Poya', 1)
# ('Pratik', 53)
# ('Pretty Little Things', 10)
# ('Princess', 14)
# ('Private Stitch', 88)
# ('Puma', 486)
# ('Q&Q by Citizen', 143)
# ('Quarter Homme', 84)
# ('R+ by Radioactive', 14)
# ('R20', 292)
# ('RAV Design', 280)
# ('REDValentino', 1)
# ('RIVER ISLAND', 1326)
# ('Radio Days @ urban TEE', 1)
# ('Radioactive', 127)
# ('Rayhanah', 43)
# ('Red Virus', 374)
# ('Redergen', 4)
# ('Redken', 2)
# ('Reebok', 262)
# ('Reka Anggun by Effi Shafinaz', 6)
# ('Rexton', 1)
# ('Rico Rinaldi', 1)
# ('Rider', 33)
# ('Rihanna', 3)
# ('Ripples', 34)
# ('Rizalman for Zalora', 68)
# ('Rocklander', 550)
# ('Rodial', 2)
# ('Royal Crown', 8)
# ('Rubaq Exclusive', 2)
# ('SCORPION', 132)
# ('SEIKO', 17)
# ('SENTINI', 17)
# ('SHOWROOM', 2)
# ('SK-II', 56)
# ('SPARROW GREEN', 2)
# ('SPURR', 16)
# ('Safety Jogger', 37)
# ('Sally Hansen', 1)
# ('Salsa', 1)
# ('Sammoni', 68)
# ('Santa Barbara Polo & Racquet Club', 21)
# ('Sapil', 23)
# ('Satryani by Shoeville', 3)
# ('Schuhster', 2)
# ('Schwarzkopf Professional', 1)
# ('Sector', 31)
# ('Selected', 30)
# ('Sephora', 166)
# ('Shapee', 1)
# ('Sidewalk', 127)
# ('Skiva', 15)
# ('Smashing Scarves by Lea Shmea', 3)
# ('Sole', 8)
# ('Something Borrowed', 386)
# ('Sorella', 11)
# ('Speedy Rhino', 11)
# ('St Bernard', 15)
# ('St Dupont', 4)
# ('Stage', 4)
# ('Staple @ Unity Store KL', 6)
# ('Starfox', 18)
# ('Steeple Jack', 116)
# ('Steve Madden', 13)
# ('Steve Madden Exclusive', 37)
# ('Steven K', 2)
# ('Stonewood', 4)
# ('Stussy', 75)
# ('Subcrew @ Unity Store KL', 5)
# ('Summit', 42)
# ('Summit Signature', 181)
# ('Superga', 22)
# ('Supreme @ Unity Store KL', 13)
# ('Swarovski Elements for ZALORA', 23)
# ('Swatch', 48)
# ('Swiss Army', 5)
# ('Swiss Military Hanowa', 157)
# ('Swiss Polo', 294)
# ('Syaiful Baharim for Zalora', 34)
# ('Sze Accessories', 32)
# ('T-Level', 25)
# ('TEAMLIFE', 1)
# ('TIMEX', 20)
# ('TULIP', 1)
# ('TWENTY2ND', 9)
# ('Tagg', 15)
# ('Te Chi-Chi', 25)
# ('Ted Baker', 16)
# ('Test', 1)
# ('Texan', 23)
# ('The Simpsons @ urban TEE', 64)
# ('Thrasher', 79)
# ('Threadless', 27)
# ('TimBuk2', 15)
# ('Timberland', 170)
# ('Titan', 192)
# ('Tomaz', 737)
# ('Tombelli', 47)
# ('Torendi', 81)
# ('Totomomo', 167)
# ('Tropicana Life', 52)
# ('UDV', 20)
# ('Unisa', 109)
# ('Unlabelled', 3)
# ('VABENE Italy', 8)
# ('VANS', 97)
# ('VERCATO', 33)
# ('VINCCI', 223)
# ('VISS', 28)
# ('Valentino Rudy', 8)
# ('Varsity', 35)
# ('Velvet', 179)
# ('Vero Moda', 28)
# ('Vessini', 24)
# ('Via Uno by Shoeville', 5)
# ('Vila', 4)
# ('Vintage1988', 2)
# ('Vivacious ', 6)
# ('Vivienne Westwood', 8)
# ('VnJ', 14)
# ('Volkswagen', 99)
# ('Voluspa', 1)
# ('Voze', 139)
# ('Vsoft Comfort', 1)
# ('Weide', 299)
# ('Weinbrenner', 91)
# ('Wendy-Joyce', 1)
# ('Wenger', 33)
# ('What About Yves', 2)
# ('Wild Channel @ Tropicana Life', 43)
# ('Wisedragon', 47)
# ('XC38', 3)
# ('XIXILI', 72)
# ('XOXO', 7)
# ('Yadah', 6)
# ('Yarmilla', 2)
# ('ZALORA', 9)
# ('ZIZTAR', 8)
# ('ZNG', 10)
# ('Zang Toi', 27)
# ('Zariya', 39)
# ('Zerra Culture', 6)
# ('Zoo York', 22)
# ('Zuco Fashion', 22)
# ('colours', 39)
# ('dressingpaula', 4)
# ('eslystyle.com', 22)
# ('kitschen', 54)
# ('nichii', 101)
# ('office', 1)
# ('urban TEE', 169)

# %% [markdown]
# 2. SQL
# a) What is the relation between Database, Schema, Tables, View in PostgreSQL / MySQL?
# b) What is the difference between a table and a view?
# c) Table reporting.items has 4 columns: Item_Code - Date - Visits - Orders
# Write a query to get total number of Visit over all Item_Codes for the day '2013-01-12'.
# Write a query to get total number of visit over all Item_Codes for every year?.
# d) As a DBA: in PostgreSQL DB, write query(s) needed to give account "buying" access to all tables currently in schema "sales", and all future Tables created in schema "sales".

# %%
select sum(Visits) from table where Date='2013-01-12'

select year(Date), sum(Visits) from table group by year(Date)


GRANT SELECT, INSERT, UPDATE, DELETE ON SCHEMA sales TO buying
GRANT SELECT, INSERT, UPDATE, DELETE ON ALL TABLES IN SCHEMA sales TO buying
GRANT SELECT, INSERT, UPDATE, DELETE ON ALL SEQUENCES IN SCHEMA sales TO buying

# %% [markdown]
# a) Write a bash script for the below set of tasks:
# [
# - connect to ftp server (host=10.11.12.13 port=22 username=helloFTP password=world)
# - download all files that have their name started with "webtrekk_marketing" into "home/Marketing Report/Data/"
# - run ZMR.py which is located in "home/Marketing Report/Scripts/"
# - run UpdateWebtrekk.sql which is located in "home/Marketing Report/Scripts/" on a PostgreSQL DB (host=10.11.12.13 port=5439 database=zalora username=helloDB password=world)
# ]
# How would you schedule the above as a cron job every day at 2.35am?

# %% [raw]
# # content of file test.sh
# # Can add return code check if there are dependencies
#
# #!/bin/sh
# echo 'Start'
# date
#
# echo 'Downloading the files'
# sshpass -p "world" scp -P 22 helloFTP@10.11.12.13:webtrekk_marketing.* home/Marketing Report/Data/
#
# if ["$?" -eq 0];then
# echo 'Executing ZMR'
# ./home/Marketing Report/Scripts/ZMR.py
#
# echo 'Executing SQL'
# EXEC SQL CONNECT TO unix:postgresql://10.11.12.13:5439/zalora USER helloDB USING world
# psql -f home/Marketing Report/Scripts/UpdateWebtrekk.sql
# EXEC SQL DISCONNECT
#
# echo 'End'
# else echo 'Download failed'
# fi

# %% [raw]
# # use crontab -l to list all the crons
# First execute "crontab -e"
# Append cron job "35 2 * * * /home/Marketing Report/Scripts/test.sh > output.log"
# Save and close the file

# %% [raw]
# b) Have a look at the folder "/programming-tasks/bash/"
# - Write a bash script to rename all files below from "zalora-*" to "Zalora-*"
# - All Zalora-* files contain a single string: "this is a test." (with a new line at the end):
#     Write a shell script to change the content of those files to all uppercase.
#     Write a shell script to remove all dot character (.) within those files.

# %%
# !for file in bash/zalora*; do mv "$file" "${file//zalora/Zalora}"; done

# %%
# !ls -lrt bash
# Out:
# total 56
# -rw-r--r--@ 1 harekrishna  staff   0 Jul  7 12:41 other-zalora-file-1.txt
# -rw-r--r--@ 1 harekrishna  staff   0 Jul  7 12:41 other-zalora-file-2.txt
# -rw-r--r--  1 harekrishna  staff  19 Nov  6 13:33 test.txt
# -rw-r--r--  1 harekrishna  staff   0 Nov  6 13:39 $file
# -rw-r--r--@ 1 harekrishna  staff  16 Nov  6 13:51 Zalora-1.txt
# -rw-r--r--@ 1 harekrishna  staff  15 Nov  6 13:51 Zalora-2.txt
# -rw-r--r--@ 1 harekrishna  staff  15 Nov  6 13:51 Zalora-3.txt
# -rw-r--r--@ 1 harekrishna  staff  15 Nov  6 13:51 Zalora-4.txt
# -rw-r--r--@ 1 harekrishna  staff  15 Nov  6 13:51 Zalora-5-extra.txt
# -rw-r--r--@ 1 harekrishna  staff  15 Nov  6 13:51 Zalora-6.txt

# %%
# !head bash/Zalora*
# Out:
# ==> bash/Zalora-1.txt <==
# this is a test.
# ==> bash/Zalora-2.txt <==
# this is a test.
# ==> bash/Zalora-3.txt <==
# this is a test.
# ==> bash/Zalora-4.txt <==
# this is a test.
# ==> bash/Zalora-5-extra.txt <==
# this is a test.

# %%
#toggles the case
# !for file in bash/Zalora*; do sed "y/abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ/ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz/" "$file" > "temp.txt"; mv "temp.txt" "$file"; done

# %%
# !head bash/Zalora*
# Out:
# ==> bash/Zalora-1.txt <==
# THIS IS A TEST.
#
# ==> bash/Zalora-2.txt <==
# THIS IS A TEST.
#
# ==> bash/Zalora-3.txt <==
# THIS IS A TEST.
#
# ==> bash/Zalora-4.txt <==
# THIS IS A TEST.
#
# ==> bash/Zalora-5-extra.txt <==
# THIS IS A TEST.

# %%
# !for file in bash/Zalora*; do sed 's/\.//g' $file > temp.txt; mv temp.txt $file; done

# %%
# !head bash/Zalora*
# Out:
# ==> bash/Zalora-1.txt <==
# THIS IS A TEST
#
# ==> bash/Zalora-2.txt <==
# THIS IS A TEST
#
# ==> bash/Zalora-3.txt <==
# THIS IS A TEST
#
# ==> bash/Zalora-4.txt <==
# THIS IS A TEST
#
# ==> bash/Zalora-5-extra.txt <==
# THIS IS A TEST
